# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('train_data.csv')

# %%
df['Age'].describe()

# %%
df['Age'].plot(kind = 'hist', bins = 20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Age'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df[df['Age'] > 65]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, PassengerId, Survived, Sex, Age, Fare, Pclass_1, Pclass_2, Pclass_3, Family_size, Title_1, Title_2, Title_3, Title_4, Emb_1, Emb_2, Emb_3]
# Index: []

# %%
df['Age'].isnull().sum()/len(df['Age'])
# Out:
# 0.0

# %%
# pclass

df['Pclass_1'].value_counts()
# Out:
# Pclass_1
# 0    599
# 1    193
# Name: count, dtype: int64

# %%
# pclass

df['Pclass_2'].value_counts()
# Out:
# Pclass_2
# 0    627
# 1    165
# Name: count, dtype: int64

# %%
# pclass

df['Pclass_3'].value_counts()
# Out:
# Pclass_3
# 1    434
# 0    358
# Name: count, dtype: int64

# %%
df['Pclass_1'].plot(kind = 'hist', bins = 20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Pclass_2'].plot(kind = 'hist', bins = 20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Pclass_3'].plot(kind = 'hist', bins = 20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
pd.crosstab(df['Pclass_1'], df['Survived'])
# Out:
# Survived    0    1
# Pclass_1
# 0         412  187
# 1          74  119
