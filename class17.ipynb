# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

data = [40, 20, 20, 60, 80, 60, 20, 60]

mean = np.mean(data)
median = np.median(data)
# mode = np.mode(data)

print("Mean:", mean)
print("Median:", median)
# print("Mode:", mode)
# Out:
# Mean: 45.0
# Median: 50.0

# %%
# Calculate range, IQR, Variouance, Standard Deviation,coefficent of variation

data = [40, 20, 20, 60, 80, 60, 20, 60]

range_val = np.ptp(data)
iqr = np.percentile(data, 75) - np.percentile(data, 25)
variance = np.var(data)
std_deviation = np.std(data)
coefficient_of_variation = std_deviation / np.mean(data)

print("Range:", range_val)
print("IQR:", iqr)
print("Variance:", variance)
print("Standard Deviation:", std_deviation)
print("Coefficient of Variation:", coefficient_of_variation)
data = [40, 20, 20, 60, 80, 60, 20, 60]
# Out:
# Range: 60
# IQR: 40.0
# Variance: 475.0
# Standard Deviation: 21.79449471770337
# Coefficient of Variation: 0.48432210483785265

# %%
x1 = np.arange(1,11)
x2 = 2 * x1 
x3 = -4 * x1
x4 = np.array([32,87,5,1,45,36,23,55,2,4])
x5 = np.array([3,8,10,4,8,2,4,15,22,4])

# %%
x6  = np.array([3,8,10,4,8,2,4,15,22,4])

# %%
sns.histplot(x6, bins = 10)
plt.xticks(np.arange(0, 23),)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(x6, bins = 10)
plt.xticks(np.arange(0, 23),)
# Out:
# ([<matplotlib.axis.XTick at 0x1f1e4310be0>,
#   <matplotlib.axis.XTick at 0x1f1e4310bb0>,
#   <matplotlib.axis.XTick at 0x1f1e423c3a0>,
#   <matplotlib.axis.XTick at 0x1f1e4353e80>,
#   <matplotlib.axis.XTick at 0x1f1e63ec970>,
#   <matplotlib.axis.XTick at 0x1f1e63ece80>,
#   <matplotlib.axis.XTick at 0x1f1e63ed930>,
#   <matplotlib.axis.XTick at 0x1f1e63ee3e0>,
#   <matplotlib.axis.XTick at 0x1f1e63eee90>,
#   <matplotlib.axis.XTick at 0x1f1e63eea40>,
#   <matplotlib.axis.XTick at 0x1f1e63ef8b0>,
#   <matplotlib.axis.XTick at 0x1f1e43107c0>,
#   <matplotlib.axis.XTick at 0x1f1e4351810>,
#   <matplotlib.axis.XTick at 0x1f1e4350eb0>,
#   <matplotlib.axis.XTick at 0x1f1e6407d30>,
#   <matplotlib.axis.XTick at 0x1f1e43522c0>,
#   <matplotlib.axis.XTick at 0x1f1e6405150>,
#   <matplotlib.axis.XTick at 0x1f1e6424ee0>,
#   <matplotlib.axis.XTick at 0x1f1e6425990>,
#   <matplotlib.axis.XTick at 0x1f1e6426440>,
#   <matplotlib.axis.XTick at 0x1f1e64074f0>,
#   <matplotlib.axis.XTick at 0x1f1e6424760>,
#   <matplotlib.axis.XTick at 0x1f1e64270a0>],
#  [Text(0, 0, '0'),
#   Text(1, 0, '1'),
#   Text(2, 0, '2'),
#   Text(3, 0, '3'),
#   Text(4, 0, '4'),
#   Text(5, 0, '5'),
#   Text(6, 0, '6'),
#   Text(7, 0, '7'),
#   Text(8, 0, '8'),
#   Text(9, 0, '9'),
#   Text(10, 0, '10'),
#   Text(11, 0, '11'),
#   Text(12, 0, '12'),
#   Text(13, 0, '13'),
#   Text(14, 0, '14'),
#   Text(15, 0, '15'),
#   Text(16, 0, '16'),
#   Text(17, 0, '17'),
#   Text(18, 0, '18'),
#   Text(19, 0, '19'),
#   Text(20, 0, '20'),
#   Text(21, 0, '21'),
#   Text(22, 0, '22')])

# %%
# Out:
# Collecting seabornNote: you may need to restart the kernel to use updated packages.
#
#   Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#      -------------------------------------- 294.9/294.9 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\ajlal\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.23.5)
# Requirement already satisfied: pandas>=1.2 in c:\users\ajlal\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (2.0.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\ajlal\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ajlal\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\ajlal\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ajlal\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ajlal\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ajlal\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ajlal\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ajlal\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ajlal\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ajlal\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.2->seaborn) (2022.7.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\ajlal\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.2->seaborn) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\ajlal\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns
import pandas as pd

# %%
x1 = np.arange(1,11)
x2 = 2 * x1 
x3 = -4 * x1
x4 = np.array([32,87,5,1,45,36,23,55,2,4])
x5 = np.array([3,8,10,4,8,2,4,15,22,4])
df = pd.DataFrame(np.transpose([x1,x2,x3,x4,x5]), columns = ['x1','x2','x3','x4','x5'])

# %%
df
# Out:
#    x1  x2  x3  x4  x5
# 0   1   2  -4  32   3
# 1   2   4  -8  87   8
# 2   3   6 -12   5  10
# 3   4   8 -16   1   4
# 4   5  10 -20  45   8
# 5   6  12 -24  36   2
# 6   7  14 -28  23   4
# 7   8  16 -32  55  15
# 8   9  18 -36   2  22
# 9  10  20 -40   4   4

# %%
df.corr()
# Out:
#           x1        x2        x3        x4        x5
# x1  1.000000  1.000000 -1.000000 -0.352684  0.366583
# x2  1.000000  1.000000 -1.000000 -0.352684  0.366583
# x3 -1.000000 -1.000000  1.000000  0.352684 -0.366583
# x4 -0.352684 -0.352684  0.352684  1.000000 -0.040759
# x5  0.366583  0.366583 -0.366583 -0.040759  1.000000

# %%
sns.heatmap(df.corr(), annot = True)
# Out:
# <Axes: >

# %%
sns.pairplot(df)
